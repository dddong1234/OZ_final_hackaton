# %% [markdown]
# # Selective EB gate — 새 seed 확정 검증
#
# 기존 취약구간 감사에서 고정한 규칙을 새 seed `31415 / 52 / 62`에만 적용한다.
# P1+EB 확률의 Top-1/Top-2 margin이 `0.05` 미만이면 P1 non-EB 확률을, 나머지는 P1+EB 확률을 사용한다. threshold·피처·blend 비율은 탐색하지 않으며 평가 데이터는 읽지 않고 제출파일도 만들지 않는다.

# %%
from pathlib import Path
import json, subprocess, sys
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.auto import tqdm
ROOT=next(p for p in (Path.cwd(),*Path.cwd().parents) if (p/'experiments/gs/notebooks/exp_model_004/common/run_selective_eb_gate.py').exists())
RUNNER=ROOT/'experiments/gs/notebooks/exp_model_004/common/run_selective_eb_gate.py'
RESULT=ROOT/'experiments/gs/notebooks/exp_model_004/result'
RUN_ID='exp-selective-eb-gate-01'
SEEDS=(31415,52,62)
RUN_EXPERIMENT=True

# %%
if RUN_EXPERIMENT:
    command=[sys.executable,str(RUNNER),'--run-id',RUN_ID,'--seeds',*[str(seed) for seed in SEEDS]]
    process=subprocess.Popen(command,stdout=subprocess.PIPE,stderr=subprocess.STDOUT,text=True,bufsize=1); tail=[]
    for line in tqdm(process.stdout,desc='selective EB gate',unit='line'):
        print(line,end=''); tail=(tail+[line])[-120:]
    if process.wait(): raise RuntimeError('runner failed:\n'+''.join(tail))
else: print('RUN_EXPERIMENT=False: existing results only')
# Out:
# selective EB gate: 0line [00:00, ?line/s]
# selective EB gate: 2line [00:06,  2.54s/line]
# row-local mutation cache:   0%|          | 0/4384 [00:00<?, ?it/s]
# selective EB gate: 5line [00:06,  1.63line/s]
# row-local mutation cache:   1%|          | 38/4384 [00:00<00:11, 371.09it/s]
# row-local mutation cache:   2%|▏         | 78/4384 [00:00<00:11, 387.51it/s]
# row-local mutation cache:   3%|▎         | 118/4384 [00:00<00:10, 392.50it/s]
# selective EB gate: 7line [00:06,  3.04line/s]
# row-local mutation cache:   4%|▎         | 158/4384 [00:00<00:10, 395.12it/s]
# row-local mutation cache:   5%|▍         | 199/4384 [00:00<00:10, 398.54it/s]
# selective EB gate: 9line [00:06,  4.81line/s]
# row-local mutation cache:   5%|▌         | 240/4384 [00:00<00:10, 399.40it/s]
# row-local mutation cache:   6%|▋         | 280/4384 [00:00<00:10, 399.32it/s]
# selective EB gate: 11line [00:07,  6.57line/s]
# row-local mutation cache:   7%|▋         | 321/4384 [00:00<00:10, 400.15it/s]
# row-local mutation cache:   8%|▊         | 362/4384 [00:00<00:09, 402.51it/s]
# selective EB gate: 13line [00:07,  7.40line/s]
# row-local mutation cache:   9%|▉         | 403/4384 [00:01<00:09, 403.28it/s]
# row-local mutation cache:  10%|█         | 444/4384 [00:01<00:09, 404.62it/s]
# selective EB gate: 15line [00:07,  8.48line/s]
# row-local mutation cache:  11%|█         | 485/4384 [00:01<00:10, 370.70it/s]
# row-local mutation cache:  12%|█▏        | 525/4384 [00:01<00:10, 377.87it/s]
# selective EB gate: 17line [00:07,  9.14line/s]
# row-local mutation cache:  13%|█▎        | 566/4384 [00:01<00:09, 384.64it/s]
# row-local mutation cache:  90%|█████████ | 3963/4384 [00:10<00:01, 402.92it/s]
# selective EB gate: 101line [00:16,  9.13line/s]
# row-local mutation cache:  91%|█████████▏| 4004/4384 [00:10<00:00, 400.54it/s]
# row-local mutation cache:  92%|█████████▏| 4045/4384 [00:10<00:00, 401.49it/s]
# selective EB gate: 103line [00:16,  9.49line/s]
# row-local mutation cache:  93%|█████████▎| 4086/4384 [00:10<00:00, 374.20it/s]
# row-local mutation cache:  94%|█████████▍| 4126/4384 [00:10<00:00, 380.08it/s]
# selective EB gate: 105line [00:16,  9.71line/s]
# row-local mutation cache:  95%|█████████▌| 4167/4384 [00:10<00:00, 387.13it/s]
# row-local mutation cache:  96%|█████████▌| 4208/4384 [00:10<00:00, 392.81it/s]
# selective EB gate: 107line [00:16,  9.75line/s]
# row-local mutation cache:  97%|█████████▋| 4249/4384 [00:10<00:00, 397.02it/s]
# row-local mutation cache:  98%|█████████▊| 4290/4384 [00:10<00:00, 398.34it/s]
# selective EB gate: 108line [00:17,  9.78line/s]
# row-local mutation cache:  99%|█████████▉| 4331/4384 [00:10<00:00, 399.29it/s]
# row-local mutation cache: 100%|█████████▉| 4372/4384 [00:11<00:00, 400.54it/s]
# row-local mutation cache: 100%|██████████| 4384/4384 [00:11<00:00, 394.49it/s]
# selective EB gate: 111line [04:15, 44.74s/line]
#           variant  seed_count  oof_macro_f1_mean  oof_macro_f1_std  delta_vs_eb_mean  delta_vs_eb_std  convergence_warning_count  leakage_check  nan_as_mutation_count
#             P1_EB           3           0.527958          0.001625          0.000000         0.000000                          0           True                      0
#         P1_non_EB           3           0.526148          0.004677         -0.001809         0.004095                          0           True                      0
# selective_EB_gate           3           0.534446          0.001027          0.006488         0.002610                          0           True                      0
# selective EB gate: 114line [04:16,  2.25s/line]

# %%
summary=pd.read_csv(RESULT/f'{RUN_ID}_3seed_summary.csv')
per_seed=pd.read_csv(RESULT/f'{RUN_ID}_per_seed.csv')
folds=pd.read_csv(RESULT/f'{RUN_ID}_fold_metrics.csv')
classes=pd.read_csv(RESULT/f'{RUN_ID}_class_metrics.csv')
usage=pd.read_csv(RESULT/f'{RUN_ID}_gate_usage.csv')
audit=json.loads((RESULT/f'{RUN_ID}_leakage_audit.json').read_text())
assert audit['test_read'] is False and audit['threshold']==0.05 and audit['threshold_retuned'] is False
assert per_seed.leakage_check.all() and per_seed.nan_as_mutation_count.eq(0).all()
display(summary); display(per_seed.sort_values(['seed','variant'])); display(usage); display(classes.sort_values('delta_gate_vs_eb').head(10))
# Out:
#              variant  seed_count  oof_macro_f1_mean  oof_macro_f1_std  \
# 0              P1_EB           3           0.527958          0.001625
# 1          P1_non_EB           3           0.526148          0.004677
# 2  selective_EB_gate           3           0.534446          0.001027
#
#    delta_vs_eb_mean  delta_vs_eb_std  convergence_warning_count  \
# 0          0.000000         0.000000                          0
# 1         -0.001809         0.004095                          0
# 2          0.006488         0.002610                          0
#
#    leakage_check  nan_as_mutation_count
# 0           True                      0
# 1           True                      0
# 2           True                      0
#     seed            variant  oof_macro_f1  delta_vs_eb  \
# 4     52              P1_EB      0.526564     0.000000
# 3     52          P1_non_EB      0.527218     0.000653
# 5     52  selective_EB_gate      0.535551     0.008986
# 7     62              P1_EB      0.529742     0.000000
# 6     62          P1_non_EB      0.530198     0.000456
# 8     62  selective_EB_gate      0.533522     0.003780
# 1  31415              P1_EB      0.527566     0.000000
# 0  31415          P1_non_EB      0.521030    -0.006536
# 2  31415  selective_EB_gate      0.534264     0.006698
#
#    convergence_warning_count  leakage_check  nan_as_mutation_count  \
# 4                          0           True                      0
# 3                          0           True                      0
# 5                          0           True                      0
# 7                          0           True                      0
# 6                          0           True                      0
# 8                          0           True                      0
# 1                          0           True                      0
# 0                          0           True                      0
# 2                          0           True                      0
#
#    runtime_seconds
# 4        77.079895
# 3        77.068796
# 5        77.091165
# 7        76.783967
# 6        76.773305
# 8        76.793936
# 1        76.624806
# 0        76.614501
# 2        76.635123
#     seed             group  support      rate  p1_non_eb_macro_f1  \
# 0  31415  low_margin_<0.05     1544  0.248992            0.216300
# 1  31415  eb_margin_>=0.05     4657  0.751008            0.590824
# 2     52  low_margin_<0.05     1560  0.251572            0.228221
# 3     52  eb_margin_>=0.05     4641  0.748428            0.599307
# 4     62  low_margin_<0.05     1588  0.256088            0.230130
# 5     62  eb_margin_>=0.05     4613  0.743912            0.609065
#
#    p1_eb_macro_f1  gate_macro_f1  margin_min  margin_max
# 0        0.217003       0.216300    0.000008    0.049837
# 1        0.605260       0.605260    0.050008    1.000000
# 2        0.200038       0.228221    0.000021    0.049934
# 3        0.608096       0.608096    0.050000    1.000000
# 4        0.213420       0.230130    0.000016    0.049961
# 5        0.611978       0.611978    0.050075    1.000000
#      seed class  support  P1_non_EB     P1_EB  selective_EB_gate  \
# 64     62  LIHC      158   0.378947  0.442623           0.388298
# 76     62  THYM       98   0.280000  0.301136           0.277620
# 14  31415  LUSC      178   0.543326  0.566327           0.543210
# 66     62  LUSC      178   0.562648  0.580977           0.560794
# 50     52  THYM       98   0.275862  0.288952           0.269795
# 38     52  LIHC      158   0.397959  0.423592           0.407311
# 0   31415   ACC       72   0.820896  0.892086           0.877698
# 26     52   ACC       72   0.855072  0.879433           0.865248
# 13  31415  LUAD      184   0.344214  0.353659           0.340426
# 73     62  STES      379   0.543978  0.552707           0.541374
#
#     delta_gate_vs_eb
# 64         -0.054325
# 76         -0.023516
# 14         -0.023117
# 66         -0.020183
# 50         -0.019157
# 38         -0.016282
# 0          -0.014388
# 26         -0.014184
# 13         -0.013233
# 73         -0.011332

# %%
pivot=per_seed.pivot(index='seed',columns='variant',values='oof_macro_f1')
ax=pivot.plot(marker='o',figsize=(8,4),title='Selective EB gate: new-seed OOF Macro F1')
ax.set_ylabel('Macro F1'); plt.tight_layout(); plt.show()
delta=per_seed[per_seed.variant.eq('selective_EB_gate')].set_index('seed').delta_vs_eb
ax=delta.plot.bar(figsize=(7,4),title='Gate delta vs P1+EB')
ax.axhline(0,color='black',linewidth=1); ax.set_ylabel('Macro F1 delta'); plt.tight_layout(); plt.show()
